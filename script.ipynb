# %%
#import libraries

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# C:\Users\Ramses\AppData\Local\Temp\ipykernel_27652\2350612576.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")

# %%
# See the data that's been imported

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
#clean up data

# %%
#Only want see USA Races, 50k or 50Mi, 2020

# %%
#Step 1 show 50Mi or 50km

# %%
df[df['Event distance/length'] == '50km']
# Out:
#          Year of event Event dates                             Event name  \
# 0                 2018  06.01.2018                    Selva Costera (CHI)
# 1                 2018  06.01.2018                    Selva Costera (CHI)
# 2                 2018  06.01.2018                    Selva Costera (CHI)
# 3                 2018  06.01.2018                    Selva Costera (CHI)
# 4                 2018  06.01.2018                    Selva Costera (CHI)
# ...                ...         ...                                    ...
# 7461089           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461090           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461091           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461092           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461093           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#combine 50km/50mi with isin

# %%
df[df['Event distance/length'].isin(['50km', '50mi'])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[(df['Event distance/length'].isin(['50km', '50mi']))   &  (df['Year of event'] == 2020)    ]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
df[df['Event name']  == 'Everglades 50 Mile Ultra Run (USA)']['Event name'].str.split('(').str.get(1)
# Out:
# 51923      USA)
# 51924      USA)
# 51925      USA)
# 51926      USA)
# 51927      USA)
#            ...
# 6417091    USA)
# 6417092    USA)
# 6417093    USA)
# 6417094    USA)
# 6417095    USA)
# Name: Event name, Length: 338, dtype: object

# %%
df[df['Event name']  == 'Everglades 50 Mile Ultra Run (USA)']['Event name'].str.split('(').str.get(1).str.split(')')
# Out:
# 51923      [USA, ]
# 51924      [USA, ]
# 51925      [USA, ]
# 51926      [USA, ]
# 51927      [USA, ]
#             ...
# 6417091    [USA, ]
# 6417092    [USA, ]
# 6417093    [USA, ]
# 6417094    [USA, ]
# 6417095    [USA, ]
# Name: Event name, Length: 338, dtype: object

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
#Combine all filters togheter

# %%
df[(df['Event distance/length'].isin(['50km'])) & (df['Year of event'] == 2020 )]
# Out:
#          Year of event     Event dates  \
# 2538609           2020  07.-09.02.2020
# 2538610           2020  07.-09.02.2020
# 2538611           2020  07.-09.02.2020
# 2538612           2020  07.-09.02.2020
# 2538613           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538609  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538610  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538611  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538612  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538613  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# ...

# %%
df2 = df[(df['Event distance/length'].isin(['50km'])) & (df['Year of event'] == 2020 )]

# %%
df2.head(10)
# Out:
#          Year of event     Event dates  \
# 2538609           2020  07.-09.02.2020
# 2538610           2020  07.-09.02.2020
# 2538611           2020  07.-09.02.2020
# 2538612           2020  07.-09.02.2020
# 2538613           2020  07.-09.02.2020
# 2538614           2020  07.-09.02.2020
# 2538615           2020  07.-09.02.2020
# 2538616           2020  07.-09.02.2020
# 2538617           2020  07.-09.02.2020
# 2538618           2020  07.-09.02.2020
#
#                                       Event name Event distance/length  \
# 2538609  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538610  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538611  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538612  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538613  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538614  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# ...

# %%
df2.shape
# Out:
# (55884, 13)

# %%
#remove (USA) from event name

# %%
df2['Event name'].str.split('(').str.get(0)
# Out:
# 2538609    Taipei 48hr Ultra Marathon - 50km
# 2538610    Taipei 48hr Ultra Marathon - 50km
# 2538611    Taipei 48hr Ultra Marathon - 50km
# 2538612    Taipei 48hr Ultra Marathon - 50km
# 2538613    Taipei 48hr Ultra Marathon - 50km
#                           ...
# 2762404                 Bison Ultra-Trail 50
# 2762405                 Bison Ultra-Trail 50
# 2762406                 Bison Ultra-Trail 50
# 2762407                 Bison Ultra-Trail 50
# 2762408                 Bison Ultra-Trail 50
# Name: Event name, Length: 55884, dtype: object

# %%
df2.head()
# Out:
#          Year of event     Event dates  \
# 2538609           2020  07.-09.02.2020
# 2538610           2020  07.-09.02.2020
# 2538611           2020  07.-09.02.2020
# 2538612           2020  07.-09.02.2020
# 2538613           2020  07.-09.02.2020
#
#                                       Event name Event distance/length  \
# 2538609  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538610  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538611  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538612  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538613  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
#
#          Event number of finishers Athlete performance Athlete club  \
# 2538609                         38           4:33:10 h          日本隊
# 2538610                         38           4:42:05 h          NaN
# 2538611                         38           4:50:59 h          NaN
# ...

# %%
#clean up athlete age

# %%
df2['athlete_age'] = 2020 - df2['Athlete year of birth']
# Out:
# C:\Users\Ramses\AppData\Local\Temp\ipykernel_27652\3897931444.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['athlete_age'] = 2020 - df2['Athlete year of birth']

# %%
#remove h from athlete preformance

# %%
df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# C:\Users\Ramses\AppData\Local\Temp\ipykernel_27652\2477507555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)

# %%
df2.head(5)
# Out:
#          Year of event     Event dates  \
# 2538609           2020  07.-09.02.2020
# 2538610           2020  07.-09.02.2020
# 2538611           2020  07.-09.02.2020
# 2538612           2020  07.-09.02.2020
# 2538613           2020  07.-09.02.2020
#
#                                       Event name Event distance/length  \
# 2538609  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538610  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538611  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538612  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538613  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
#
#          Event number of finishers Athlete performance Athlete club  \
# 2538609                         38             4:33:10          日本隊
# 2538610                         38             4:42:05          NaN
# 2538611                         38             4:50:59          NaN
# ...

# %%
#drop columns: Athlete Club, Athlete Contry, Athlete year of birth, Athlete age category

# %%
df2 = df2.drop(['Athlete club', 'Athlete country', 'Athlete year of birth', 'Athlete age category'], axis =1)

# %%
df2.head()
# Out:
#          Year of event     Event dates  \
# 2538609           2020  07.-09.02.2020
# 2538610           2020  07.-09.02.2020
# 2538611           2020  07.-09.02.2020
# 2538612           2020  07.-09.02.2020
# 2538613           2020  07.-09.02.2020
#
#                                       Event name Event distance/length  \
# 2538609  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538610  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538611  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538612  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538613  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
#
#          Event number of finishers Athlete performance Athlete gender  \
# 2538609                         38             4:33:10              M
# 2538610                         38             4:42:05              M
# 2538611                         38             4:50:59              M
# ...

# %%
#clean up null values

# %%
df2.isna().sum()
# Out:
# Year of event                   0
# Event dates                     0
# Event name                      0
# Event distance/length           0
# Event number of finishers       0
# Athlete performance             0
# Athlete gender                  0
# Athlete average speed           0
# Athlete ID                      0
# athlete_age                  3370
# dtype: int64

# %%
df2[df2['athlete_age'].isna() == 1]
# Out:
#          Year of event Event dates                                Event name  \
# 2538819           2020  07.02.2020  Dead Sea Marathon Ein Bokek - 50km (ISR)
# 2538831           2020  07.02.2020  Dead Sea Marathon Ein Bokek - 50km (ISR)
# 2538904           2020  07.02.2020  Dead Sea Marathon Ein Bokek - 50km (ISR)
# 2538913           2020  07.02.2020  Dead Sea Marathon Ein Bokek - 50km (ISR)
# 2538927           2020  07.02.2020  Dead Sea Marathon Ein Bokek - 50km (ISR)
# ...                ...         ...                                       ...
# 2761020           2020  03.10.2020    China Meiling Int. Trail Running (CHN)
# 2761021           2020  03.10.2020    China Meiling Int. Trail Running (CHN)
# 2761027           2020  03.10.2020    China Meiling Int. Trail Running (CHN)
# 2761041           2020  03.10.2020    China Meiling Int. Trail Running (CHN)
# 2762359           2020  03.10.2020                Bison Ultra-Trail 50 (POL)
#
# ...

# %%
df2 = df2.dropna()

# %%
df2.shape
# Out:
# (52514, 10)

# %%
#check for dupes

# %%
df2[df2.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, athlete_age]
# Index: []

# %%
#reset index

# %%
df.reset_index(drop = True)
# Out:
#          Year of event Event dates                                Event name  \
# 0                 2018  06.01.2018                       Selva Costera (CHI)
# 1                 2018  06.01.2018                       Selva Costera (CHI)
# 2                 2018  06.01.2018                       Selva Costera (CHI)
# 3                 2018  06.01.2018                       Selva Costera (CHI)
# 4                 2018  06.01.2018                       Selva Costera (CHI)
# ...                ...         ...                                       ...
# 7461190           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461191           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461192           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461193           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461194           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
#
# ...

# %%
#fix types

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# athlete_age                  float64
# dtype: object

# %%
df2['athlete_age'] = df2['athlete_age'].astype(int)

# %%
df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# athlete_age                    int32
# dtype: object

# %%
df2.head()
# Out:
#          Year of event     Event dates  \
# 2538609           2020  07.-09.02.2020
# 2538610           2020  07.-09.02.2020
# 2538611           2020  07.-09.02.2020
# 2538612           2020  07.-09.02.2020
# 2538613           2020  07.-09.02.2020
#
#                                       Event name Event distance/length  \
# 2538609  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538610  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538611  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538612  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538613  Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
#
#          Event number of finishers Athlete performance Athlete gender  \
# 2538609                         38             4:33:10              M
# 2538610                         38             4:42:05              M
# 2538611                         38             4:50:59              M
# ...

# %%
#rename columns

# %%
#Year of event                  int64
#Event dates                   object
#Event name                    object
#Event distance/length         object
#Event number of finishers      int64
#Athlete performance           object
#Athlete gender                object
#Athlete average speed        float64
#Athlete ID                     int64
#athlete_age                    int32
#dtype: object

# %%
df2 = df2.rename(columns = { 'Year of event': 'year' , 
                             'Event dates': 'race_day' , 
                             'Event name': 'race_name',
                           })

# %%
df2.head()
# Out:
#          year        race_day                                race_name  \
# 2538609  2020  07.-09.02.2020  Taipei 48hr Ultra Marathon - 50km (TPE)
# 2538610  2020  07.-09.02.2020  Taipei 48hr Ultra Marathon - 50km (TPE)
# 2538611  2020  07.-09.02.2020  Taipei 48hr Ultra Marathon - 50km (TPE)
# 2538612  2020  07.-09.02.2020  Taipei 48hr Ultra Marathon - 50km (TPE)
# 2538613  2020  07.-09.02.2020  Taipei 48hr Ultra Marathon - 50km (TPE)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2538609                  50km                         38             4:33:10
# 2538610                  50km                         38             4:42:05
# 2538611                  50km                         38             4:50:59
# 2538612                  50km                         38             4:54:22
# 2538613                  50km                         38             4:59:08
#
#         Athlete gender  Athlete average speed  Athlete ID  athlete_age
# ...

# %%
#reorder columns

# %%
df3 = df2[['race_day', 'race_name', 'athlete_age']]

# %%
df3.head(10)
# Out:
#                race_day                                race_name  athlete_age
# 2538609  07.-09.02.2020  Taipei 48hr Ultra Marathon - 50km (TPE)           55
# 2538610  07.-09.02.2020  Taipei 48hr Ultra Marathon - 50km (TPE)           44
# 2538611  07.-09.02.2020  Taipei 48hr Ultra Marathon - 50km (TPE)           46
# 2538612  07.-09.02.2020  Taipei 48hr Ultra Marathon - 50km (TPE)           56
# 2538613  07.-09.02.2020  Taipei 48hr Ultra Marathon - 50km (TPE)           51
# 2538614  07.-09.02.2020  Taipei 48hr Ultra Marathon - 50km (TPE)           56
# 2538615  07.-09.02.2020  Taipei 48hr Ultra Marathon - 50km (TPE)           56
# 2538616  07.-09.02.2020  Taipei 48hr Ultra Marathon - 50km (TPE)           51
# 2538617  07.-09.02.2020  Taipei 48hr Ultra Marathon - 50km (TPE)           46
# 2538618  07.-09.02.2020  Taipei 48hr Ultra Marathon - 50km (TPE)           48

# %%
#find 2 races in 2020 - Selva Costera (CHI)

# %%
df3[df3['race_name']  == 'Selva Costera (CHI)']
# Out:
#            race_day            race_name  athlete_age
# 2567352  04.01.2020  Selva Costera (CHI)           32
# 2567353  04.01.2020  Selva Costera (CHI)           39
# 2567354  04.01.2020  Selva Costera (CHI)           39
# 2567355  04.01.2020  Selva Costera (CHI)           32
# 2567356  04.01.2020  Selva Costera (CHI)           39
# 2567357  04.01.2020  Selva Costera (CHI)           32
# 2567358  04.01.2020  Selva Costera (CHI)           31
# 2567359  04.01.2020  Selva Costera (CHI)           39
# 2567360  04.01.2020  Selva Costera (CHI)           54
# 2567361  04.01.2020  Selva Costera (CHI)           51
# 2567362  04.01.2020  Selva Costera (CHI)           27
# 2567363  04.01.2020  Selva Costera (CHI)           35
# 2567364  04.01.2020  Selva Costera (CHI)           37
# 2567365  04.01.2020  Selva Costera (CHI)           46
# 2567366  04.01.2020  Selva Costera (CHI)           26
# 2567367  04.01.2020  Selva Costera (CHI)           49
# ...
